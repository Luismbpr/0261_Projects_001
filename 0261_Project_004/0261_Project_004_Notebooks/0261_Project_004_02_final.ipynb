# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:190%; text-align:center; display:fill; border-radius:5px; background-color:#42659A; overflow:hidden; font-weight:250; font-family:helvetica;"> 0261_Project_004 - 02 </div>

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:190%; text-align:center; display:fill; border-radius:5px; background-color:#617A9A; overflow:hidden; font-weight:270; font-family:helvetica;"> General Project Steps</div>
# <br>
# <H3 style="padding:1px; font-family:helvetica; padding-left:20px">Project Description and Information</H3>
#
# <H3 style="padding:1px; font-family:helvetica; padding-left:20px">Web Scraping Financial Information</H3>
#
# <H3 style="padding:1px; font-family:helvetica; padding-left:20px"> Backtesting Strategies</H3>
#
# <H3 style="padding:1px; font-family:helvetica; padding-left:20px"> Index Tracking</H3>
#
# <H3 style="padding:1px; font-family:helvetica; padding-left:20px"> Forward Testing Strategies</H3>

# %% [markdown]
# ### Note: This is not financial advice and should not be treated as such. This is for educational purposes only.

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:190%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Data Loading and Processing</div>

# %%
import numpy as np
import pandas as pd
import unicodedata
import yfinance as yf

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#plt.style.use("seaborn")

# %%
data = pd.read_csv("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Data/dji001.csv",
                   parse_dates=["Date"], index_col="Date")

### Using previous dji.csv from other notebook
#data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
#                 parse_dates=["Date"], index_col="Date")

data = pd.read_csv("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Data/Previous Data/dji.csv",
parse_dates=["Date"], index_col="Date")

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:190%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Data Visualization & Returns</div>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#plt.style.use("seaborn")

# %%
df01 = data.loc["2010-01-01":"2020-03-31", "Close"].to_frame()

# %%
df01.plot(figsize = (8, 6), fontsize = 12)

plt.xticks(rotation=90, fontsize = 10)
plt.xlabel("")
plt.ylabel("Closing Price USD", fontsize = 10)

plt.title("Closing Price USD", fontsize = 10)
plt.legend("",fontsize = 12)## Using an empty string so it does not show legend
plt.grid(alpha=0.0)
plt.savefig('')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
plt.scatter(x=df01.index, y=df01["Close"], s=0.5)
#plt.xlabel("Period", fontsize=10)
plt.ylabel("Closing Price USD", fontsize = 10)
plt.title("Closing Price USD", fontsize = 12)
plt.grid(alpha=0.3)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0001_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
## Return - Percent change
df01["Return"] = df01.pct_change(periods = 1, fill_method = 'pad', limit=None, freq=None)

# %%
## Double plot
ylabel=""
ylabel="Return"
df01.plot(figsize=(8,6), secondary_y="Return", mark_right=True, fontsize=10)
plt.title("Closing Price and Percentage Return", fontsize=12)
plt.xlabel(ylabel, fontdict=None, labelpad=None)
plt.ylabel(ylabel, fontdict=None, labelpad=None)
#plt.legend(fontsize=10)
plt.grid(alpha=0.6)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0002_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
##https://stackoverflow.com/questions/35072400/how-to-set-a-secondary-y-axis-in-python
## https://matplotlib.org/stable/gallery/subplots_axes_and_figures/secondary_axis.html#sphx-glr-gallery-subplots-axes-and-figures-secondary-axis-py
fig, ax = plt.subplots(figsize=(8, 6), layout='constrained')

#ax1 = df["DJI_Close"].plot()
ax1 = df01["Close"].plot()


#ax2 = df["DJI_Return"].plot(secondary_y=True, alpha=0.6)
ax2 = df01["Return"].plot(secondary_y=True, alpha=0.6)
ax1.set_ylabel("Closing Price", fontsize=12)
ax2.set_ylabel("Return", fontsize=12)

#axes.set_xlabel("")


#sec_ax = axes.secondary_yaxis('right')
#sec_ax.set_ylabel('2ylabel')

#axes.secondary_yaxis()
fig = ax.get_figure()
plt.show()

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

df01 = data.loc["2010-01-01":"2020-03-31", "Close"].to_frame()
df01["Return"] = df01.pct_change()
df01.dropna(inplace=True)

df01.rename(columns={'Close':"DJI_Close", 'Return':"DJI_Return"}, inplace=True)

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:190%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Backtesting Strategies</div>

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:120%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Backtesting A Simple Momentum Strategy</div>

# %% [markdown]
# Positions:
#
# | Position | Description |
# |--|--|
# | +1 | Investing in DJI (**Long** Position) |
# | -1 | Short Selling DJI (**Short** Position) |
# | 0  | No Position (**Neutral**) |
#
# Strategies:
#
# -_Buy and Hold_ (Basic Strategy - passive): Initially Investing into DJI and do nothing (Position: +1 on any given day)
#
# -__Simple Momentum__ (active Strategy to be tested): <br>
# __a) Investing (+1)__ into DJI tomorrow if today´s return was __positive__ <br>
# __b) Short selling (-1)__ DJI tomorrow if today´s return was __negative__

# %% [markdown]
# Strategies to Follow:
# - **Buy and Hold** (Basic strategy - passive) Initially investing into DJI and do nothing (Position: +1 on any given day)
#
#
# - **Simple Momentum** (Active Strategy to be tested):
# **a) Investing (+1)** into DJI tomorrow if today's return was **positive**
# **b) Short selling (-1)** DJI tomorrow if today's return was **negative**

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

df01 = data.loc["2010-01-01":"2020-03-31", "Close"].to_frame()
df01["Return"] = df01.pct_change()
df01.dropna(inplace=True)

df01.rename(columns={'Close':"DJI_Close", 'Return':"DJI_Return"}, inplace=True)

df01["Position"] = np.sign(df01["DJI_Return"])
df01["Strategy_Ret"] = df01["Position"].shift(periods = 1, freq = None, axis = 0) * df01["DJI_Return"]
df01["Strategy"] = df01["Strategy_Ret"].add(other=1, axis=0, level=None)
df01["Strategy"] = df01["Strategy_Ret"].add(other=1, axis=0, level=None, fill_value=0).cumprod() * df01.iloc[0,0]
#df01.head()

# %%
df01.head()
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_Ret      Strategy
# Date
# 2010-01-05  10572.019531   -0.001128      -1.0           NaN  10572.019531
# 2010-01-06  10573.679688    0.000157       1.0     -0.000157  10570.359375
# 2010-01-07  10606.860352    0.003138       1.0      0.003138  10603.529620
# 2010-01-08  10618.190430    0.001068       1.0      0.001068  10614.856140
# 2010-01-11  10663.990234    0.004313       1.0      0.004313  10660.641563

# %% [markdown]
# df01.iloc[0,0] is the same as df01["DJI_Close"]

# %% [markdown]
# df01[0:10]

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

df01 = data.loc["2010-01-01":"2020-03-31", "Close"].to_frame()
df01["Return"] = df01.pct_change()
df01.dropna(inplace=True)

df01.rename(columns={'Close':"DJI_Close", 'Return':"DJI_Return"}, inplace=True)
df01["Position"] = np.sign(df01["DJI_Return"])
df01["Strategy_Ret"] = df01["Position"].shift(periods = 1, freq = None, axis = 0) * df01["DJI_Return"]
df01["Strategy"] = df01["Strategy_Ret"].add(other=1, axis=0, level=None, fill_value=0).cumprod() * df01.iloc[0,0]

# %%
df01.head()
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_Ret      Strategy
# Date
# 2010-01-05  10572.019531   -0.001128      -1.0           NaN  10572.019531
# 2010-01-06  10573.679688    0.000157       1.0     -0.000157  10570.359375
# 2010-01-07  10606.860352    0.003138       1.0      0.003138  10603.529620
# 2010-01-08  10618.190430    0.001068       1.0      0.001068  10614.856140
# 2010-01-11  10663.990234    0.004313       1.0      0.004313  10660.641563

# %%
df01[["DJI_Close", "Strategy_Ret"]].plot(figsize = (8, 6), fontsize = 15)
#df[["DJI_Close", "Strategy"]].plot(figsize = (15, 10), fontsize = 15)
plt.xticks(rotation=45, fontsize = 15)
plt.xticks(rotation=45, fontsize = 15)

plt.xlabel("", fontsize = 15)
plt.ylabel("Return", fontsize = 15)
plt.title("Simple Momentum Strategy", fontsize = 15)
plt.legend(loc="best", fontsize = 12)
plt.show()

# %%
def summary_ann(returns):
    summary = returns.agg(["mean", "std"]).T
    summary["Return"] = summary["mean"] * 252
    summary["Risk"] = summary["std"] * np.sqrt(252)
    summary.drop(columns=["mean", "std"], inplace=True)
    return summary

# %%
summary_strategy_01 = summary_ann(df01[["DJI_Return","Strategy_Ret"]])
summary_strategy_01
# Out:
#                 Return      Risk
# DJI_Return    0.087212  0.167896
# Strategy_Ret -0.057966  0.167946

# %%
summary_strategy_01_02 = summary_ann(df01[["DJI_Return","Strategy_Ret"]])
summary_strategy_01_02.rename({"DJI_Return":"Buy and Hold_df01", "Strategy_Ret":"Simple Momentum_df01"}, inplace=True)
summary_strategy_01_02
# Out:
#                         Return      Risk
# Buy and Hold_df01     0.087212  0.167896
# Simple Momentum_df01 -0.057966  0.167946

# %% [markdown]
# Strategy 01
#
#                                            Return 	  Risk
# Buy and hold strategy ->  DJI_Return      0.087212 	0.167896
#      Momentum strategy -> Strategy_Ret 	 -0.057966 	0.167946
#
# Annual Return and Annualized Risk
# The risk is the same, but the return varies a lot between strategies.
# The strategy is underperforming in terms of return.
#
# On an annualized basis there is a return:
# For the Momentum strategy of -5.79%
# For the Buy and Hold of 8.72%
#
# Conclusion:
# The Momentum strategy underperforms against the Buy and Hold strategy
# The Momentum strategy is not beneficial as a long-term strategy
# The Buy and Hold strategy is working well in the long term compared to the momentum strategy
# summary_strategy_01["Return"]["DJI_Return"]

# %%
## Buy and hold strategy
#summary_strategy_01["Return"]["DJI_Return"]
summary_strategy_01["Return"].index[0]
summary_strategy_01["Return"].values[0]

## Momentum strategy
#summary_strategy_01["Return"]["Strategy_Ret"]
summary_strategy_01["Return"].index[1]
summary_strategy_01["Return"].values[1]

#figure = plt.figure(figsize=(7, 5))
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))
#axes[0].bar(summary_strategy_01["Return"].index, summary_strategy_01["Return"].values, label="Return")
axes[0].bar(summary_strategy_01["Return"].index[0], summary_strategy_01["Return"].values[0], label="Buy and hold strategy - Return")
axes[1].bar(summary_strategy_01["Return"].index[1], summary_strategy_01["Return"].values[1], label="Momentum strategy - Return")

axes[0].set_yticks(np.arange(-.4, 0.4, 0.2))
axes[1].set_yticks(np.arange(-.4, 0.4, 0.2))
#axes[2].set_yticks(np.arange(-1.0, 0.6, 0.2))

axes[0].set_title("Buy and hold strategy")
axes[1].set_title("Momentum strategy")

plt.suptitle("Strategy_01", fontsize = 12)

#plt.legend(loc=(1.01, 0.8),fontsize = 10)
#axes[0].legend(loc="best",fontsize = 10)
#axes[1].legend(loc="best",fontsize = 10)
plt.show()

# %%
## Buy and hold strategy
#summary_strategy_01["Return"]["DJI_Return"]
summary_strategy_01["Risk"].index[0]
summary_strategy_01["Risk"].values[0]

## Momentum strategy
#summary_strategy_01["Return"]["Strategy_Ret"]
summary_strategy_01["Risk"].index[1]
summary_strategy_01["Risk"].values[1]

#figure = plt.figure(figsize=(7, 5))
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))
#axes[0].bar(summary_strategy_01["Return"].index, summary_strategy_01["Return"].values, label="Return")
axes[0].bar(summary_strategy_01["Risk"].index[0], summary_strategy_01["Risk"].values[0], label="Buy and hold strategy - Risk")
axes[1].bar(summary_strategy_01["Risk"].index[1], summary_strategy_01["Risk"].values[1], label="Momentum strategy - Risk")

axes[0].set_yticks(np.arange(-.4, 0.6, 0.2))
axes[1].set_yticks(np.arange(-.4, 0.6, 0.2))
#axes[2].set_yticks(np.arange(-1.0, 0.6, 0.2))

axes[0].set_title("Buy and hold strategy")
axes[1].set_title("Momentum strategy")

plt.suptitle("Strategy_01", fontsize = 12)

#plt.legend(loc=(1.01, 0.8),fontsize = 10)
#axes[0].legend(loc="best",fontsize = 10)
#axes[1].legend(loc="best",fontsize = 10)
plt.show()

# %%
### Buy and hold strategy
##summary_strategy_01["Return"]["DJI_Return"]
#summary_strategy_01["Return"].index[0]
#summary_strategy_01["Return"].values[0]

### Momentum strategy
##summary_strategy_01["Return"]["Strategy_Ret"]
#summary_strategy_01["Return"].index[1]
#summary_strategy_01["Return"].values[1]

#figure = plt.figure(figsize=(7, 5))
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

axes[0][0].bar(summary_strategy_01["Return"].index[0], summary_strategy_01["Return"].values[0], label="Buy and hold strategy - Return")
axes[0][1].bar(summary_strategy_01["Return"].index[1], summary_strategy_01["Return"].values[1], label="Momentum strategy - Return")

axes[0][0].set_yticks(np.arange(-.4, 0.4, 0.2))
axes[0][1].set_yticks(np.arange(-.4, 0.4, 0.2))

axes[0][0].set_title("Buy and hold strategy - Return")
axes[0][1].set_title("Momentum strategy - Return")


axes[1][0].bar(summary_strategy_01["Risk"].index[0], summary_strategy_01["Risk"].values[0], label="Buy and hold strategy - Risk")
axes[1][1].bar(summary_strategy_01["Risk"].index[1], summary_strategy_01["Risk"].values[1], label="Momentum strategy - Risk")

axes[1][0].set_yticks(np.arange(-.4, 0.6, 0.4))
axes[1][1].set_yticks(np.arange(-.4, 0.6, 0.4))

axes[1][0].set_title("Buy and hold strategy - Risk")
axes[1][1].set_title("Momentum strategy - Risk")

plt.suptitle("Strategy_01", fontsize = 12)

#plt.legend(loc=(1.01, 0.8),fontsize = 10)
#axes[0].legend(loc="best",fontsize = 10)
#axes[1].legend(loc="best",fontsize = 10)
plt.show()

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:120%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Backtesting A Simple Contrarian Strategy</div>

# %% [markdown]
# Positions:
#
# | Position | Description |
# |--|--|
# | +1 | Investing in DJI (**Long** Position) |
# | -1 | Short Selling DJI (**Short** Position) |
# | 0 | No Position (**Neutral**) |
#
# Strategies:
#
# -_Buy and Hold_ (Basic Strategy): Initially Investing into DJI and do nothing (Position: +1 on all days)
#
# Strategy 01
# -_Simple Momentum_ (tested): <br>
# _a) Investing (+1)_ into DJI tomorrow if today´s return was _positive_ <br>
# _b) Short selling (-1)_ DJI tomorrow if today´s return was _negative_
#
# Strategy 02
# -__Simple Contrarian__ (active Strategy to be tested): <br>
# __a) Investing (+1)__ into DJI tomorrow if today´s return was __negative__ <br>
# __b) Short selling (-1)__ DJI tomorrow if today´s return was __positive__

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

#df02 = data.loc["2010-01-01":"2020-03-31", "Close"].to_frame()
df02 = data.loc["2010":,"Close"].to_frame()
df02["Return"] = df02.pct_change()
#df02["DJI_Return"] = df02.Close.pct_change()

df02.dropna(inplace=True)

df02.rename(columns={'Close':"DJI_Close", 'Return':"DJI_Return"}, inplace=True)
#df02.columns = ["DJI_Close","DJI_Return"]

df02["Position"] = -np.sign(df02["DJI_Return"])
df02["Strategy_Ret"] = df02["Position"].shift() * df02["DJI_Return"]
df02["Strategy"] = df02["Strategy_Ret"].add(1, axis=0, fill_value=0).cumprod() * df02.iloc[0,0]

# %%
df02.head()
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_Ret      Strategy
# Date
# 2010-01-05  10572.019531   -0.001128       1.0           NaN  10572.019531
# 2010-01-06  10573.679688    0.000157      -1.0      0.000157  10573.679688
# 2010-01-07  10606.860352    0.003138      -1.0     -0.003138  10540.499023
# 2010-01-08  10618.190430    0.001068      -1.0     -0.001068  10529.239831
# 2010-01-11  10663.990234    0.004313      -1.0     -0.004313  10483.823700

# %%
df02[["DJI_Close", "Strategy"]].plot(figsize = (8, 6), fontsize = 12)
#df[["DJI_Close", "Strategy"]].plot(figsize = (15, 10), fontsize = 15)
plt.title("Simple Contrarian Strategy", fontsize = 12)
plt.legend(loc="best", fontsize = 10)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0003_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
summary_strategy_02 = summary_ann(df02[["DJI_Return","Strategy_Ret"]])
summary_strategy_02
# Out:
#                 Return      Risk
# DJI_Return    0.087212  0.167896
# Strategy_Ret  0.057966  0.167946

# %% [markdown]
#                 Return 	       Risk
# DJI_Return
# Strategy_Ret
#
# Simple Contrarian Strategy
#
#
# Strategy 02
#
#                                            Return 	   Risk
# Buy and hold strategy  -> DJI_Return      0.087212 	 0.167896
#    Contrarian strategy -> Strategy_Ret 	  0.057966 	 0.167946
#
#
# Annual Return and Annualized Risk
# The risk is the same, but the return varies a lot between strategies.
# The strategy is underperforming in terms of return.
#
# On an annualized basis there is a return:
# For the Momentum strategy of 5.79%
# For the Buy and Hold of 8.72%
#
# Conclusion:
# The Contrarian strategy underperforms against the Buy and Hold strategy
# The Contrarian strategy is not beneficial as a long-term strategy
# The Buy and Hold strategy is working well in the long term compared to the momentum strategy
#
#
# ---------------------------
#
# * The buy and hold stratgy is performing better than the Simple Momentum Strategy
# * The buy and hold strategy is performing better than the Contrarian Strategy

# %%
#summary_strategy_01_02 = summary_ann(df01[["DJI_Return","Strategy_Ret"]])
#summary_strategy_01_02.rename({"DJI_Return":"Buy_and_Hold_df01", "Strategy_Ret":"Simple_Momentum_df01"}, inplace=True)
#summary_strategy_01_02

summary_strategy_02_02 = summary_ann(df02[["DJI_Return","Strategy_Ret"]])
summary_strategy_02_02.rename({"DJI_Return":"Buy_and_Hold_df02", "Strategy_Ret":"Simple_Contrarian_df02"}, inplace=True)
summary_strategy_02_02
# Out:
#                           Return      Risk
# Buy_and_Hold_df02       0.087212  0.167896
# Simple_Contrarian_df02  0.057966  0.167946

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:120%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">More Complex Strategies & Backtesting Vs Fitting</div>

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

#df02 = data.loc["2010-01-01":"2020-03-31", "Close"].to_frame()
df03 = data.loc["2010":,"Close"].to_frame()
df03["DJI_Return"] = df03["Close"].pct_change()
#df03["DJI_Return"] = df03.Close.pct_change()

df03.dropna(inplace=True)

df03.rename(columns={'Close':"DJI_Close", 'Return':"DJI_Return"}, inplace=True)
#df03.columns = ["DJI_Close","DJI_Return"]

# %%
### Simple Contrarian Strategy
## If return is positive will short the next day
## If return + next day will be -1

### If DJI_Return is + will short the next day
### If DJI_Return is - will buy the next day
df03["Position"] = np.where(df03["DJI_Return"] > 0.0, -1, 1)
df03["Strategy_Ret"] = df03["Position"].shift() * df03["DJI_Return"]
df03["Strategy"] = df03["Strategy_Ret"].add(1, fill_value=0).cumprod() * df03.iloc[0,0]

# %%
df03.head()
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_Ret      Strategy
# Date
# 2010-01-05  10572.019531   -0.001128         1           NaN  10572.019531
# 2010-01-06  10573.679688    0.000157        -1      0.000157  10573.679688
# 2010-01-07  10606.860352    0.003138        -1     -0.003138  10540.499023
# 2010-01-08  10618.190430    0.001068        -1     -0.001068  10529.239831
# 2010-01-11  10663.990234    0.004313        -1     -0.004313  10483.823700

# %%
df03[["DJI_Close", "Strategy"]].plot(figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.legend(fontsize=10)
plt.title("Simple Contrarian Strategy", fontsize=12)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0004_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
summary_strategy_03 = summary_ann(df03[["DJI_Return","Strategy_Ret"]])
summary_strategy_03
# Out:
#                 Return      Risk
# DJI_Return    0.087212  0.167896
# Strategy_Ret  0.056947  0.167980

# %%
summary_strategy_03 = summary_ann(df03[["DJI_Return","Strategy_Ret"]])
#summary_strategy_03

#summary_strategy_03
summary_strategy_03.rename({"DJI_Return":"DJI_str_03_Buy_and_hold",
                            "Strategy_Ret":"str_03_contrarian"
                           })
# Out:
#                            Return      Risk
# DJI_str_03_Buy_and_hold  0.087212  0.167896
# str_03_contrarian        0.056947  0.167980

# %%
#summary_strategy_01_02 = summary_ann(df01[["DJI_Return","Strategy_Ret"]])
#summary_strategy_01_02.rename({"DJI_Return":"Buy_and_Hold_df01", "Strategy_Ret":"Simple_Momentum_df01"}, inplace=True)
#summary_strategy_01_02

#summary_strategy_02_02 = summary_ann(df02[["DJI_Return","Strategy_Ret"]])
#summary_strategy_02_02.rename({"DJI_Return":"Buy_and_Hold_df02", "Strategy_Ret":"Simple_Contrarian_df02"}, inplace=True)
#summary_strategy_02_02

summary_strategy_03_02 = summary_ann(df02[["DJI_Return","Strategy_Ret"]])
summary_strategy_03_02.rename({"DJI_Return":"Buy_and_Hold_df03", "Strategy_Ret":"Simple_Contrarian_df03"}, inplace=True)
summary_strategy_03_02
# Out:
#                           Return      Risk
# Buy_and_Hold_df03       0.087212  0.167896
# Simple_Contrarian_df03  0.057966  0.167946

# %% [markdown]
# Strategy 03
#
#                          	Return      	Risk
# DJI_str_03_Buy_and_hold 	0.087212 	0.167896
#       str_03_contrarian 	0.056947 	0.167980
#
#
# Annual Return and Annualized Risk
# The risk is the same, but the return varies a lot between strategies.
# Contrarian Strategy is underperforming buy and hold
#
# On an annualized basis there is a return:
# For the Buy and hold 8.72%
# For the Contrarian 5.69%
#
# Conclusion:
# The Contrarian strategy underperforms against the Buy and Hold strategy
# The Contrarian strategy is not beneficial as a long-term strategy
# The Buy and Hold strategy is working well in the long term compared to the momentum strategy
#
#
# ---------------------------

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

df04 = data.loc["2010":, "Close"].to_frame()
df04["DJI_Return"] = df04["Close"].pct_change()
df04.columns = ["DJI_Close","DJI_Return"]
df04.dropna(inplace=True)

# %%
### Short Selling being Neutral -> Short selling is not allowed

### If DJI_Return is + will *short* the next day Note: Isn't 
### If DJI_Return is - will buy the next day
### IF DJI + Will do nothing,
df04["Position"] = np.where(df04["DJI_Return"] > 0.0, 0, 1)
df04["Strategy_Ret"] = df04["Position"].shift() * df04["DJI_Return"]
df04["Strategy"] = df04["Strategy_Ret"].add(1, fill_value=0).cumprod() * df04.iloc[0,0]

# %%
df04.head()
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_Ret      Strategy
# Date
# 2010-01-05  10572.019531   -0.001128         1           NaN  10572.019531
# 2010-01-06  10573.679688    0.000157         0      0.000157  10573.679688
# 2010-01-07  10606.860352    0.003138         0      0.000000  10573.679688
# 2010-01-08  10618.190430    0.001068         0      0.000000  10573.679688
# 2010-01-11  10663.990234    0.004313         0      0.000000  10573.679688

# %%
df04[["DJI_Close", "Strategy"]].plot(figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.legend(fontsize=10)
plt.title("Short Selling Being Neutral", fontsize=12)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0005_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
summary_strategy_04 = summary_ann(df04[["DJI_Return","Strategy_Ret"]])
#summary_strategy_04

#summary_strategy_04
summary_strategy_04.rename({"DJI_Return":"DJI_str_04_Buy_and_hold",
                            "Strategy_Ret":"str_04_Short_selling_neutral"
                           })
# Out:
#                                 Return      Risk
# DJI_str_04_Buy_and_hold       0.087212  0.167896
# str_04_Short_selling_neutral  0.072152  0.125301

# %%
(summary_strategy_04["Risk"][0] - summary_strategy_04["Risk"][1])*100
# Out:
# 4.259536083768381

# %%
summary_strategy_04["Return"][0] * 100
# Out:
# 8.721181521753248

# %%
summary_strategy_04["Return"][1] * 100
# Out:
# 7.215155318310305

# %%
(summary_strategy_04["Return"][0] * 100) - (summary_strategy_04["Return"][1] * 100)
# Out:
# 1.5060262034429428

# %% [markdown]
#  	Return 	Risk
# DJI_str_04_Buy_and_hold 	0.087212 	0.167896
#       str_04_contrarian 	0.072152 	0.125301
#
#
# The risk is higher for the buy and hold for 4.26% compared to the str_04_contrarian
#
# DJI_str_04_Buy_and_hold 8.72%
#       str_04_contrarian 7.22%
# The Simple Contrarian Strategy underperforms buy and hold Strategy by 1.51%
# There is an added risk of 4.26%

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:120%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">More Complex Strategies 02</div>

# %% [markdown]
# Positions:
#
# | Position | Description |
# |--|--|
# | +1 | Investing in DJI (**Long** Position) |
# | -1 | Short Selling DJI (**Short** Position) |
#
# Strategies:
#
# -_Buy and Hold_ (Basic Strategy): Initially Investing into DJI and do nothing (Position: +1 on all days)
#
# Strategy
# -_Buy or Short if it is 1%_: <br>
# _a) Investing (+1)_ into DJI tomorrow if today´s return was _lower or equal to 1%_ <br>
# _b) Short selling (-1)_ into DJI tomorrow if today´s return was _higher than 1%_

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

df05 = data.loc["2010":, "Close"].to_frame()

df05["DJI_Return"] = df05["Close"].pct_change()
df05.columns= ["DJI_Close","DJI_Return"]
df05.dropna(inplace=True)

# %%
df05.head(2)
# Out:
#                DJI_Close  DJI_Return
# Date
# 2010-01-05  10572.019531   -0.001128
# 2010-01-06  10573.679688    0.000157

# %%
### For short selling
##df05["Position"] = np.where(df05["DJI_Return"] > 0.0, -1, 1)
### For short selling being neutral when short selling is not allowed
##df05["Position"] = np.where(df05["DJI_Return"] > 0.0, 0, 1)

df05["Position"] = np.where(df05["DJI_Return"] > 0.01, -1, 1)

df05["Strategy_Ret"] = df05["Position"].shift() * df05["DJI_Return"]
df05["Strategy"] = df05["Strategy_Ret"].add(1, fill_value=0).cumprod() * df05.iloc[0,0]

# %%
df05.head(10)
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_Ret      Strategy
# Date
# 2010-01-05  10572.019531   -0.001128         1           NaN  10572.019531
# 2010-01-06  10573.679688    0.000157         1      0.000157  10573.679688
# 2010-01-07  10606.860352    0.003138         1      0.003138  10606.860352
# 2010-01-08  10618.190430    0.001068         1      0.001068  10618.190430
# 2010-01-11  10663.990234    0.004313         1      0.004313  10663.990234
# 2010-01-12  10627.259766   -0.003444         1     -0.003444  10627.259766
# 2010-01-13  10680.769531    0.005035         1      0.005035  10680.769531
# 2010-01-14  10710.549805    0.002788         1      0.002788  10710.549805
# 2010-01-15  10609.650391   -0.009421         1     -0.009421  10609.650391
# 2010-01-19  10725.429688    0.010913        -1      0.010913  10725.429687

# %%
df05[["DJI_Close", "Strategy"]].plot(figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.legend(fontsize=10)
plt.title("Strategy 1%", fontsize=12)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0006_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
summary_strategy_05 = summary_ann(df05[["DJI_Return","Strategy_Ret"]])
#summary_strategy_04

#summary_strategy_04
#summary_strategy_05.rename({"DJI_Return":"DJI_str_05_Buy_and_hold",
#                            "Strategy_Ret":"str_05_1_percent"
#                           })

summary_strategy_05_02 = summary_ann(df02[["DJI_Return","Strategy_Ret"]])
summary_strategy_05_02.rename({"DJI_Return":"Buy_and_Hold_df05", "Strategy_Ret":"Buy_or_Short_1Percent_df05"}, inplace=True)
summary_strategy_05_02
# Out:
#                               Return      Risk
# Buy_and_Hold_df05           0.087212  0.167896
# Buy_or_Short_1Percent_df05  0.057966  0.167946

# %%
print(f"DJI_str_05_Buy_and_hold: {np.round(((summary_strategy_05['Return'][0])*100), 4)}")

print(f"str_05_1_percent: {np.round(((summary_strategy_05['Return'][1])*100), 4)}")

print(f"str_05_1_percent - DJI_str_05_Buy_and_hold: {np.round(((summary_strategy_05['Return'][1])*100 - (summary_strategy_05['Return'][0])*100), 4)}")
# Out:
# DJI_str_05_Buy_and_hold: 8.7212
# str_05_1_percent: 17.4262
# str_05_1_percent - DJI_str_05_Buy_and_hold: 8.705

# %% [markdown]
# The buy and hold strategy is underperforming.
# A Daily return greater than 1 percent is high. Whenver there are daily returns greater than 1% there are a lot of investors, which take the profits the following day. Therefore in the following day we have a negative return.
#
# Whenever the today's return is higher than 1% then tomorrow will short sell the Dow Jones Index
# Whenever the today's return is lower or equal than 1% then tomorrow will take the long position
# df["Position"] = np.where(df["DJI_Return"] > 0.01, -1, 1)
#
# * Backtest
#
# This strategy clearly outperforms the buy and hold strategy
# A Daily return greater than 1% is pretty high whenever there are daily returns greater than 1% then there are a lot of investors, which take the profits the following day and therefore in the following day we have a negative return
#
#
#
#
#                              Return 	  Risk
# DJI_str_05_Buy_and_hold 	0.087212 	0.167896
#        str_05_1_percent 	0.174262 	0.167659
#
#
#
# The risk is almost the same for both strategies.
# The return for the buy and hold strategy is 8.70497 %
# The return for the new strategy is 17.42615
# There is a 8.70497 % difference between both strategies
#
# The new strategy outperforms the buy and hold strategy
# Note: Even if the strategy seems to out-perform the basic strategy, the following issues need to be considered/analyzed as well:
#
# * Backtesting vs. Fitting -> Was the strategy **fitted** and optimized on **historical data**? **Forward Testing** is required
# * **Transaction Costs** -> Changing positions trigger Cost. Include costs
# * **Tax Effects** -> Changing positions can trigger (earlier) Tax Payments. Include Taxes

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:120%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Simple Moving Averages SMA</div>

# %% [markdown]
# Will Backtest the strategy with Simple Moving Averages (SMA)
#
# Moving Averages (also known as Crossovers) are a popular strategy for technical traders
# See if this new strategy can outperform Buy and Hold Strategy
#
# Moving Average Crossovers
# Price trends persist over a longer time period
# In contrast to a simple moving average strategy, which only considers the return of only one day to find the strategy for the next day. Here we are taking into account a longer period and longer price trends

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

df06 = data.loc["2010":, "Close"].to_frame()
df06["DJI_Return"] = df06["Close"].pct_change()
df06.columns= ["DJI_Close","DJI_Return"]
df06.dropna(inplace=True)

# %%
###Very popular rolling window for the Simple Moving Average is 50
### Taking into account the immediate preceding 50 days
### For each and every timestamp
### Calculate the immediate preceding 50 trading days
df06["SMA50"] = df06["DJI_Close"].rolling(window=50,
                                          min_periods= None,
                                          center= False,
                                          win_type= None,
                                          on= None,
                                          axis= 0,
                                          closed= None,
                                          step= None,
                                          method= 'single').mean()

# %%
df06[48:53]
# Out:
#                DJI_Close  DJI_Return         SMA50
# Date
# 2010-03-16  10685.980469    0.004119           NaN
# 2010-03-17  10733.669922    0.004463  10392.891211
# 2010-03-18  10779.169922    0.004239  10397.034219
# 2010-03-19  10741.980469   -0.003450  10400.400234
# 2010-03-22  10785.889648    0.004088  10403.980820

# %%
###### Visualizing the daily prices and the Simple Moving Average 50
###### 

df06[["DJI_Close", "SMA50"]].plot(figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.title("SMA Window: 50")
plt.legend(fontsize=10)
plt.show()

###### The SMA 50 smoothens the daily prices

# %%
### Another popular window is 200. Simple Moving Average 200
### Calculate the immediate preceding 50 trading days
df06["SMA200"] = df06["DJI_Close"].rolling(window=200,
                                          min_periods= None,
                                          center= False,
                                          win_type= None,
                                          on= None,
                                          axis= 0,
                                          closed= None,
                                          step= None,
                                          method= 'single').mean()

# %%
###### Visualizing the daily prices and the Simple Moving Average of 50 and 200
df06[["SMA200", "SMA50"]].plot(figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.title("SMA Window 50 and SMA Window 200")
plt.legend(fontsize=10)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0007_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()


### The SMA50 smoothes the daily prices and the SMA200 smoothes even more
### The SMA50 catches more recent price trends and reacts faster to the changing prices

### In the COVID19 Prices
### The SMA50 falls faster than the SMA200 since it takes into account the most recent 50 days

### SMA Crossovers
### There are places where both Simple Moving Averages cross over each other
### Will build a strategy on these crossovers

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:120%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Backtesting Simple Moving Average Strategies</div>

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))

df07 = data.loc["2010":, "Close"].to_frame()
df07["DJI_Return"] = df07["Close"].pct_change()
df07.columns= ["DJI_Close","DJI_Return"]
df07.dropna(inplace=True)

# %%
df07["SMA50"] = df07["DJI_Close"].rolling(window=50).mean()
df07["SMA200"] = df07["DJI_Close"].rolling(window=200).mean()

# %%
df07[["SMA200", "SMA50"]].plot(figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.title("SMA Window 50 and SMA Window 200")
plt.legend(fontsize=10)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0008_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
## Dropping missing values
## Will be starting 200 days layer - 

#df07.head().index###'2010-01-05',
df07.dropna(inplace=True)

# %%
df07[["SMA200", "SMA50"]].plot(figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.title("SMA Window 50 and SMA Window 200 after dropping missing values")
plt.legend(fontsize=10)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0008_002.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:120%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Other Strategy</div>

# %% [markdown]
# * Buy and Hold - Basic Strategy
#     Initially investing into DJI and doing nothing
#
# | Position | |
# |--|--|--|
# | Buy and hold | Position: + | On all days |
# | Buy and hold | Position: - | No Short Selling |
# | SMA50 vs SMA200 | Position: + | SMA50 > SMA200 |
# | SMA50 vs SMA200 | Position: - | SMA50 < SMA200 |
#
# * SMA Crossover (Momentum) - Strategy to be tested:
# a) Investing (+1): SMA50 > SMA200
# b) Short Selling (-1): SMA50 < SMA200
#
# Technical traders argue that the most recent price trends they persist on the near future.
# Whenever the SMA50 crosses with a larger window (SMA200 in this case). Then this is a signal to buy or go long, because the most recent prices will persist and rise in the near future.
#
# In contrast to that:
# When the SMA50 crosses below the SMA200, this is a signal to sell because the most recent tren falling prices will persist in the near future.
#
# Comparing this strategy with buy and hold.

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))
df08 = data.loc["2010":, "Close"].to_frame()
df08["DJI_Return"] = df08["Close"].pct_change()
df08.columns= ["DJI_Close","DJI_Return"]
df08.dropna(inplace=True)

# %%
### Creating SMA50 and SMA200
df08["SMA50"] = df08["DJI_Close"].rolling(window=50).mean()
df08["SMA200"] = df08["DJI_Close"].rolling(window=200).mean()

# %%
### 
### Substracting SMA50 - SMA200

df08["Position"] = np.sign(df08["SMA50"].sub(df08["SMA200"]))

# %%
df08
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position
# Date
# 2010-01-05  10572.019531   -0.001128           NaN           NaN       NaN
# 2010-01-06  10573.679688    0.000157           NaN           NaN       NaN
# 2010-01-07  10606.860352    0.003138           NaN           NaN       NaN
# 2010-01-08  10618.190430    0.001068           NaN           NaN       NaN
# 2010-01-11  10663.990234    0.004313           NaN           NaN       NaN
# ...                  ...         ...           ...           ...       ...
# 2020-03-24  20704.910156    0.113650  26708.547930  27010.902910      -1.0
# 2020-03-25  21200.550781    0.023938  26554.417930  26986.592266      -1.0
# 2020-03-26  22552.169922    0.063754  26426.667930  26969.110566      -1.0
# 2020-03-27  21636.779297   -0.040590  26278.799102  26947.270313      -1.0
# 2020-03-30  22327.480469    0.031923  26139.395898  26928.373867      -1.0
#
# [2576 rows x 5 columns]

# %%
df08.dropna(inplace=True)

# %%
df08
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position
# Date
# 2010-10-19  10978.620117   -0.014813  10582.089805  10507.098203       1.0
# 2010-10-20  11107.969727    0.011782  10591.364199  10509.777954       1.0
# 2010-10-21  11146.570312    0.003475  10606.719004  10512.642407       1.0
# 2010-10-22  11132.559570   -0.001257  10622.971191  10515.270903       1.0
# 2010-10-25  11164.049805    0.002829  10640.189180  10518.000200       1.0
# ...                  ...         ...           ...           ...       ...
# 2020-03-24  20704.910156    0.113650  26708.547930  27010.902910      -1.0
# 2020-03-25  21200.550781    0.023938  26554.417930  26986.592266      -1.0
# 2020-03-26  22552.169922    0.063754  26426.667930  26969.110566      -1.0
# 2020-03-27  21636.779297   -0.040590  26278.799102  26947.270313      -1.0
# 2020-03-30  22327.480469    0.031923  26139.395898  26928.373867      -1.0
#
# [2377 rows x 5 columns]

# %%
df08.columns
# Out:
# Index(['DJI_Close', 'DJI_Return', 'SMA50', 'SMA200', 'Position'], dtype='object')

# %%
### The Position is either + or - 1
### Starting with SMA50 greater than SMA200


#df08[['SMA50', 'SMA200']].plot(figsize=(12,10), fontsize=14)
df08[['SMA50', 'SMA200', 'Position']].plot(secondary_y="Position", figsize=(8,6), fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("",fontsize=10)
#plt.ylabel("Return ($)")
plt.ylabel("Position (0 or 1)",fontsize=10)


plt.title("SMA50 vs SMA200 and Position",fontsize=12)
#plt.legend(loc=(0.0095, 0.8), fontsize=14)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0009_002.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
df08["Strategy_Ret"] = df08["Position"].shift() * df08["DJI_Return"]

df08["Strategy"] = df08["Strategy_Ret"].add(1, fill_value=0).cumprod() * df08.iloc[0,0]

# %%
df08.head()
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position  \
# Date
# 2010-10-19  10978.620117   -0.014813  10582.089805  10507.098203       1.0
# 2010-10-20  11107.969727    0.011782  10591.364199  10509.777954       1.0
# 2010-10-21  11146.570312    0.003475  10606.719004  10512.642407       1.0
# 2010-10-22  11132.559570   -0.001257  10622.971191  10515.270903       1.0
# 2010-10-25  11164.049805    0.002829  10640.189180  10518.000200       1.0
#
#             Strategy_Ret      Strategy
# Date
# 2010-10-19           NaN  10978.620117
# 2010-10-20      0.011782  11107.969727
# 2010-10-21      0.003475  11146.570312
# 2010-10-22     -0.001257  11132.559570
# 2010-10-25      0.002829  11164.049805

# %%
df08["Strategy_Ret"].head()
# Out:
# Date
# 2010-10-19         NaN
# 2010-10-20    0.011782
# 2010-10-21    0.003475
# 2010-10-22   -0.001257
# 2010-10-25    0.002829
# Name: Strategy_Ret, dtype: float64

# %%
### Strategy Comparison

df08[["DJI_Close", "Strategy"]].plot(figsize=(8,6), fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.title("SMA Strategy vs Buy and Hold")
plt.legend(fontsize=10)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0010_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()
### The strategy underperforms compared to the buy and hold strategy
### At least this holds true for a longer time period

# %%
#summary_strategy_08 = summary_ann(df08[["DJI_Return", "Strategy_Ret"]])
#summary_strategy_08

summary_strategy_08_02 = summary_ann(df08[["DJI_Return","Strategy_Ret"]])
summary_strategy_08_02.rename({"DJI_Return":"Buy_and_Hold_df08", "Strategy_Ret":"SMA50_sub_SMA200_df08"}, inplace=True)
summary_strategy_08_02
# Out:
#                          Return      Risk
# Buy_and_Hold_df08      0.087819  0.167604
# SMA50_sub_SMA200_df08 -0.022887  0.167655

# %% [markdown]
# Annualized Risk and Return
#
#                    	Return  	Risk
# DJI_Return 	     0.087819 	0.167604
# Strategy_Ret 	-0.022887 	0.167655
#
#
# Buy and Hold outperforms the Crossover Momentum Strategy in the long run
# It actually loses money with a return of -2.28%
# We could not find evidence whether this crossover momentum strategy over performs buy and hold
#
# Can also test the contrarian strategy, whenever SMA50 is above SMA200, then we take the short position
# SMA50 > SMA200 - Short (-) then we take the short position

# %% [markdown]
# ###### We could not find any evidence whether this momentum crossover momentum strategy over performs buy and hold
# ###### Can also test the contrarian strategy, whenever SMA50 is above than SMA200 then we take the short position

# %% [markdown]
# <div style="padding:8px; color:#ECEEF1; margin:0.3; font-size:120%; text-align:center; display:fill; border-radius:5px; background-color:#5274aa; overflow:hidden; font-weight:270; font-family:helvetica;">Other Strategy - Contrarian SMA</div>

# %% [markdown]
# * Buy and Hold - Basic Strategy
#     Initially investing into DJI and doing nothing
#
# | Position | |
# |--|--|--|
# | Buy and hold | Position: + | On all days |
# | Buy and hold | Position: - | No Short Selling |
# | SMA50 vs SMA200 | Position: + | SMA50 < SMA200 |
# | SMA50 vs SMA200 | Position: - | SMA50 > SMA200 |
#
# * SMA Crossover (Momentum) - Strategy to be tested:
# a) Investing (+1): SMA50 < SMA200
# b) Short Selling (-1): SMA50 > SMA200
#
# In contrast to that:
# When the SMA50 crosses below the SMA200, this is a signal to buy (contrarian strategy)
#
# Comparing this strategy with buy and hold.

# %%
### Using previous dji.csv from other notebook
data = pd.read_csv("/Users/luis/Documents/Programming/Courses_Programming/0261 1) Python Data Science with Pandas Master 12 Advanced Projects 2022/venv_0261_DS_12_Advanced_Projects_390/Projects/0261_Project_10/0261_Project_10_Data/Project_10_Materials/dji.csv",
                 parse_dates=["Date"], index_col="Date"
                )
#print(len(data))
df09 = data.loc["2010":, "Close"].to_frame()
df09["DJI_Return"] = df09["Close"].pct_change()
df09.columns = ["DJI_Close", "DJI_Return"]
df09.dropna(inplace=True)

# %%
df09["SMA50"] = df09["DJI_Close"].rolling(window=50).mean()
df09["SMA200"] = df09["DJI_Close"].rolling(window=200).mean()
df09.dropna(inplace=True)

# %%
### Contrarian strategy
### SMA50 - SMA200
### Error:
#df09["Position"] = -np.sign(df09["SMA50"]).sub(df09["SMA200"])
## Solution:
df09["Position"] = -np.sign(df09["SMA50"].sub(df09["SMA200"]))

# %%
##Start here 2

### The Position is either + or - 1
### Starting with SMA50 greater than SMA200

#df09[['SMA50', 'SMA200', 'Position']].plot(secondary_y="Position", figsize=(12,10), fontsize=14)
df09[["SMA50", "SMA200", "Position"]].plot(secondary_y = "Position",figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.title("SMA50 vs SMA200 and Position (Contrarian Strategy)",fontsize=10)
#plt.legend(fontsize=14)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0011_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

###### We have the opposite positions of what we had before

# %%
df09.head()
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position
# Date
# 2010-10-19  10978.620117   -0.014813  10582.089805  10507.098203      -1.0
# 2010-10-20  11107.969727    0.011782  10591.364199  10509.777954      -1.0
# 2010-10-21  11146.570312    0.003475  10606.719004  10512.642407      -1.0
# 2010-10-22  11132.559570   -0.001257  10622.971191  10515.270903      -1.0
# 2010-10-25  11164.049805    0.002829  10640.189180  10518.000200      -1.0

# %%
df09["Strategy_Ret"] = df09["Position"].shift() * df09["DJI_Return"]

df09["Strategy"] = df09["Strategy_Ret"].add(1, fill_value=0).cumprod() * df09.iloc[0,0]

# %%
df09.head()
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position  \
# Date
# 2010-10-19  10978.620117   -0.014813  10582.089805  10507.098203      -1.0
# 2010-10-20  11107.969727    0.011782  10591.364199  10509.777954      -1.0
# 2010-10-21  11146.570312    0.003475  10606.719004  10512.642407      -1.0
# 2010-10-22  11132.559570   -0.001257  10622.971191  10515.270903      -1.0
# 2010-10-25  11164.049805    0.002829  10640.189180  10518.000200      -1.0
#
#             Strategy_Ret      Strategy
# Date
# 2010-10-19           NaN  10978.620117
# 2010-10-20     -0.011782  10849.270508
# 2010-10-21     -0.003475  10811.568911
# 2010-10-22      0.001257  10825.158571
# 2010-10-25     -0.002829  10794.537870

# %%
### Strategy Comparison
df09[["DJI_Close","Strategy"]].plot(figsize=(8,6), fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("")
plt.ylabel("")
plt.title("SMA Strategy vs Buy and Hold",fontsize=12)
plt.legend(fontsize=10)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0012_001.png", 
            bbox_inches='tight', dpi=90)
plt.show()

# %%
#summary_strategy_09 = summary_ann(returns=df09[["DJI_Return", "Strategy_Ret"]])
#summary_strategy_09

summary_strategy_09_02 = summary_ann(df09[["DJI_Return","Strategy_Ret"]])
summary_strategy_09_02.rename({"DJI_Return":"Buy_and_Hold_df09", "Strategy_Ret":"SMA50_sub_SMA200_contr_df09"}, inplace=True)
summary_strategy_09_02
# Out:
#                                Return      Risk
# Buy_and_Hold_df09            0.087819  0.167604
# SMA50_sub_SMA200_contr_df09  0.022887  0.167655

# %% [markdown]
# ##### summary_strategy_09
#
#               Return 	Risk
# DJI_Return 	0.087819 	0.167604
# Strategy_Ret 	0.022887 	0.167655

# %%
#summary_strategy_01_02 = summary_ann(df01[["DJI_Return","Strategy_Ret"]])
#summary_strategy_01_02.rename({"DJI_Return":"Buy_and_Hold_df01", "Strategy_Ret":"Simple_Momentum_df01"}, inplace=True)
#summary_strategy_01_02

#summary_strategy_02_02 = summary_ann(df02[["DJI_Return","Strategy_Ret"]])
#summary_strategy_02_02.rename({"DJI_Return":"Buy_and_Hold_df02", "Strategy_Ret":"Simple_Contrarian_df02"}, inplace=True)
#summary_strategy_02_02

summary_strategy_03_02 = summary_ann(df02[["DJI_Return","Strategy_Ret"]])
summary_strategy_03_02.rename({"DJI_Return":"Buy_and_Hold_df03", "Strategy_Ret":"Simple_Contrarian_df03"}, inplace=True)
summary_strategy_03_02

summary_strategy_04_02 = summary_ann(df04[["DJI_Return","Strategy_Ret"]])
summary_strategy_04_02.rename({"DJI_Return":"Buy_and_Hold_df04", "Strategy_Ret":"Neutral_Short_Selling_df04"}, inplace=True)
summary_strategy_04_02

summary_strategy_05_02 = summary_ann(df05[["DJI_Return","Strategy_Ret"]])
summary_strategy_05_02.rename({"DJI_Return":"Buy_and_Hold_df05", "Strategy_Ret":"Buy_or_Short_1Percent_df05"}, inplace=True)
summary_strategy_05_02

#df06, df07, SMA50 comparing to SMA200

summary_strategy_08_02 = summary_ann(df08[["DJI_Return","Strategy_Ret"]])
summary_strategy_08_02.rename({"DJI_Return":"Buy_and_Hold_df08", "Strategy_Ret":"SMA50_sub_SMA200_df08"}, inplace=True)
summary_strategy_08_02

summary_strategy_09_02 = summary_ann(df09[["DJI_Return","Strategy_Ret"]])
summary_strategy_09_02.rename({"DJI_Return":"Buy_and_Hold_df09", "Strategy_Ret":"SMA50_sub_SMA200_contr_df09"}, inplace=True)
summary_strategy_09_02
# Out:
#                                Return      Risk
# Buy_and_Hold_df09            0.087819  0.167604
# SMA50_sub_SMA200_contr_df09  0.022887  0.167655

# %%
all_strategies_df = pd.concat([summary_strategy_03_02,
           summary_strategy_04_02,
           summary_strategy_05_02,
           summary_strategy_08_02,
           summary_strategy_09_02])

all_strategies_df
# Out:
#                                Return      Risk
# Buy_and_Hold_df03            0.087212  0.167896
# Simple_Contrarian_df03       0.057966  0.167946
# Buy_and_Hold_df04            0.087212  0.167896
# Neutral_Short_Selling_df04   0.072152  0.125301
# Buy_and_Hold_df05            0.087212  0.167896
# Buy_or_Short_1Percent_df05   0.174262  0.167659
# Buy_and_Hold_df08            0.087819  0.167604
# SMA50_sub_SMA200_df08       -0.022887  0.167655
# Buy_and_Hold_df09            0.087819  0.167604
# SMA50_sub_SMA200_contr_df09  0.022887  0.167655

# %%
all_strategies_df = all_strategies_df.drop(labels=['Buy_and_Hold_df04', 'Buy_and_Hold_df05', 'Buy_and_Hold_df08', 'Buy_and_Hold_df09'],
                       axis=0)
all_strategies_df
# Out:
#                                Return      Risk
# Buy_and_Hold_df03            0.087212  0.167896
# Simple_Contrarian_df03       0.057966  0.167946
# Neutral_Short_Selling_df04   0.072152  0.125301
# Buy_or_Short_1Percent_df05   0.174262  0.167659
# SMA50_sub_SMA200_df08       -0.022887  0.167655
# SMA50_sub_SMA200_contr_df09  0.022887  0.167655

# %%
all_strategies_df = all_strategies_df.rename({"Buy_and_Hold_df03":"Buy_and_Hold_df"})
all_strategies_df
# Out:
#                                Return      Risk
# Buy_and_Hold_df              0.087212  0.167896
# Simple_Contrarian_df03       0.057966  0.167946
# Neutral_Short_Selling_df04   0.072152  0.125301
# Buy_or_Short_1Percent_df05   0.174262  0.167659
# SMA50_sub_SMA200_df08       -0.022887  0.167655
# SMA50_sub_SMA200_contr_df09  0.022887  0.167655

# %%
### Saving Results
all_strategies_df.to_csv("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Data/Results/02/all_strategies_df.csv")

# %%
all_strategies_df_sorted = all_strategies_df.sort_values(by="Return")
all_strategies_df_sorted

plt.figure(figsize=(6,4))
plt.bar(x=all_strategies_df_sorted["Return"].index, height=all_strategies_df_sorted["Return"].values)

plt.xticks(np.arange(0, len(all_strategies_df_sorted.index)),all_strategies_df_sorted.index, rotation=90)
plt.xlabel("")
plt.ylabel("Return")

plt.title("Strategy Results", fontsize=12)

plt.show()

# %%
all_strategies_df_sorted = all_strategies_df.sort_values(by="Return")
all_strategies_df_sorted

plt.figure(figsize=(6,4))
#plt.bar(x=all_strategies_df_sorted["Return"].index, height=all_strategies_df_sorted["Return"].values)
plt.bar(x=all_strategies_df_sorted["Return"].index, height=(all_strategies_df_sorted["Return"].values*100))

plt.xticks(np.arange(0, len(all_strategies_df_sorted.index)),all_strategies_df_sorted.index, rotation=90, fontsize=8)
plt.xlabel("", fontsize=10)
plt.ylabel("Return (%)")

plt.title("Strategy Results", fontsize=12)
plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0013_001.png", 
            bbox_inches='tight', dpi=90)

plt.show()

# %%
## Source
## https://stackoverflow.com/questions/22311139/bar-chart-how-to-choose-color-if-value-is-positive-vs-value-is-negative
#data['values'].plot(kind='barh',
#                    color=(data['values'] > 0).map({True: 'g',
#                                                    False: 'r'}))

all_strategies_df_sorted = all_strategies_df.sort_values(by="Return")
all_strategies_df_sorted

plt.figure(figsize=(6,4))
#plt.bar(x=all_strategies_df_sorted["Return"].index, height=all_strategies_df_sorted["Return"].values)
plt.bar(x=all_strategies_df_sorted["Return"].index, height=(all_strategies_df_sorted["Return"].values*100),
        #color = "tab:blue")
       color=(all_strategies_df_sorted["Return"] > 0).map({True:'tab:blue', False:'darkgrey'}))

plt.xticks(np.arange(0, len(all_strategies_df_sorted.index)),all_strategies_df_sorted.index, rotation=90, fontsize=8)
plt.xlabel("")
plt.ylabel("Return (%)")

plt.title("Strategy Results - Returns", fontsize=12)

plt.savefig("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_004/0261_Project_004/0261_Project_004_Notebooks/Images/Saved_Images/02/0013_002.png", 
            bbox_inches='tight', dpi=90)
plt.show()
