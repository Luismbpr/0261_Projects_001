# %% [markdown]
# # Model Result Gathering and saving in csv

# %% [markdown]
# ### Validation
#
# linreg_model_001_001
# MAE: 49564.9322051044  -> 49564.9322
# RMSE: 67706.03188712957 -> 67706.0319
#
#
# y_mean:206864.41315519012
# poly_reg_train_mae_error_deg1: [49549.965899364506]
# poly_reg_valid_mae_error_deg1: [49564.9322051044]
# poly_reg_train_rmse_error_deg1: [68487.30666948423]
# poly_reg_valid_rmse_error_deg1: [67706.03188712957]
#
#
# y_mean:206864.41315519012
# poly_reg_train_mae_error_deg4: [33666.07622760095]
# poly_reg_valid_mae_error_deg4: [63110017.519814424]
# poly_reg_train_rmse_error_deg4: [48759.10064441612]
# poly_reg_valid_rmse_error_deg4: [2850688206.059887]
#
# y_mean:206864.41315519012
# poly_reg_train_mae_error_deg5: [28690.253484394216]
# poly_reg_valid_mae_error_deg5: [18580293.58694403]
# poly_reg_train_rmse_error_deg5: [42000.390493522995]
# poly_reg_valid_rmse_error_deg5: [836435049.3990898]
#
#
# y_mean:206864.41315519012
# poly_reg_train_mae_error_deg6: [20783.815048039214]
# poly_reg_valid_mae_error_deg6: [8321417.911808935]
# poly_reg_train_rmse_error_deg6: [32068.50881015292]
# poly_reg_valid_rmse_error_deg6: [331446727.6123541]
#
#
#
# grid_elasticnet_model_001_001
# MAE: 49551.93502135185  -> 49551.9350
# RMSE: 67672.26049668764 -> 67672.2605
#
#
#
# grid_elasticnet_model_001_002
# MAE: 49557.13332102286  -> 49557.1333
# RMSE: 67685.12328588415 -> 67685.1233
#
#
#
#
#
# grid_elasticnet_model_001_003
# MAE: 49555.83305722182  -> 49555.8331
# RMSE: 67681.8269674355 -> 67681.8270
#
# ####################################################################################
# grid_logreg_model_001_001
# LogisticRegression(C=59948425.03189421, l1_ratio=0.6666666666666666,
#                    max_iter=5000, multi_class='ovr', penalty='elasticnet',
#                    solver='saga', tol=0.1)
#
# grid_logreg_model_001_001.best_params_
# {'C': 59948425.03189421, 'l1_ratio': 0.6666666666666666}
#
#
# print(grid_logreg_model_001_001.best_estimator_)
# LogisticRegression(C=59948425.03189421, l1_ratio=0.6666666666666666,
#                    max_iter=5000, multi_class='ovr', penalty='elasticnet',
#                    solver='saga', tol=0.1)
#
#
#
# mae_score_logreg_model_001_001_valid: 153733.41997063142
#
# rmse_score_logreg_model_001_001_valid: 198670.25865081637
#
#
# ####################################################################################
#
#
#
#
# knn_model_001_002
# MAE: 41275.47466960352  -> 41275.4747
# RMSE: 61374.900387250156 -> 61374.9004
#
#
# grid_svm_model_001_001
# MAE: 84320.52948403715  -> 84320.5295
# RMSE: 113044.25429996425 -> 113044.2543
#
#
#
#
# grid_tree_model_001_001
# MAE: 41109.13803230543  -> 41109.1380
# RMSE: 64120.244954724265 -> 64120.2450
#
#
#
# grid_tree_model_001_002
# MAE: 41109.13803230543  -> 41109.1380
# RMSE: 64120.244954724265 -> 64120.2450
#
#
#
#
# grid_tree_model_001_003
# MAE: 43144.52912383749  -> 43144.5291
# RMSE: 66740.0776336217 -> 66740.0776
#
# grid_forest_model_001_001
# MAE: 31867.046889378365  -> 31867.0469
# RMSE: 48100.59363344365 -> 48100.5936
#
#
#
#
# grid_forest_model_001_002
# MAE: 31878.649262289353  -> 31878.6493
# RMSE: 48090.53655289738 -> 48090.5366
#
#
#
# grid_adaboost_model_001_001
# MAE: 61086.588231772716  -> 61086.5882
# RMSE: 76693.2085742247 -> 76693.2086
#
#
#
# grid_adaboost_model_001_002
# MAE: 67291.50349112618  -> 67291.5035
# RMSE: 81686.01116244897 -> 81686.0112
#
#
#
# grid_adaboost_model_001_003
# MAE: 57364.95767226333  -> 57364.9577
# RMSE: 74216.26980500946 -> 74216.2698
#
#
#
#
# grid_gradboost_model_001_001
# MAE: 33055.989282643226  -> 33055.9893
# RMSE: 48681.06989826054 -> 48681.0699
#
#
#
# grid_gradboost_model_001_002
# MAE: 32810.95400567314  -> 32810.9540
# RMSE: 48457.531555013564 -> 48457.5316
#
#
# grid_XGBRegressor_model_001_001
# MAE: 39170.28156548274  -> 39170.2816
# RMSE: 57131.60231542059 -> 57131.6023
#
# grid_XGBRFRegressor_model_001_001
# MAE: 45182.25031357073  -> 45182.2503
# RMSE: 63844.16962078191 -> 63844.1696

# %% [markdown]
# y_mean:206864.41315519012
#
#
#
# linreg_model_001_001
# MAE: 49564.9322051044  -> 49564.9322
# RMSE: 67706.03188712957 -> 67706.0319
#
#
#
# model_lin_reg_poly_deg1
# poly_reg_valid_mae_error_deg1: [49564.9322051044]
# poly_reg_valid_rmse_error_deg1: [67706.03188712957]
#
#
# grid_elasticnet_model_001_001
# MAE: 49551.93502135185  -> 49551.9350
# RMSE: 67672.26049668764 -> 67672.2605
#
#
# grid_elasticnet_model_001_002
# MAE: 49557.13332102286  -> 49557.1333
# RMSE: 67685.12328588415 -> 67685.1233
#
#
#
# grid_elasticnet_model_001_003
# MAE: 49555.83305722182  -> 49555.8331
# RMSE: 67681.8269674355 -> 67681.8270
#
#
# grid_logreg_model_001_001
# Xxx
#
#
#
# knn_model_001_002
# MAE: 41275.47466960352  -> 41275.4747
# RMSE: 61374.900387250156 -> 61374.9004
#
#
#
# grid_svm_model_001_001
# MAE: 84320.52948403715  -> 84320.5295
# RMSE: 113044.25429996425 -> 113044.2543
#
#
#
#
# grid_tree_model_001_001
# MAE: 41109.13803230543  -> 41109.1380
# RMSE: 64120.244954724265 -> 64120.2450
#
#
#
# grid_tree_model_001_002
# MAE: 41109.13803230543  -> 41109.1380
# RMSE: 64120.244954724265 -> 64120.2450
#
#
# grid_tree_model_001_003
# MAE: 43144.52912383749  -> 43144.5291
# RMSE: 66740.0776336217 -> 66740.0776
#
#
#
#
# grid_forest_model_001_001
# MAE: 31867.046889378365  -> 31867.0469
# RMSE: 48100.59363344365 -> 48100.5936
#
#
#
# grid_forest_model_001_002
# MAE: 31878.649262289353  -> 31878.6493
# RMSE: 48090.53655289738 -> 48090.5366
#
#
#
# grid_adaboost_model_001_001
# MAE: 61086.588231772716  -> 61086.5882
# RMSE: 76693.2085742247 -> 76693.2086
#
#
#
#
# grid_adaboost_model_001_002
# MAE: 67291.50349112618  -> 67291.5035
# RMSE: 81686.01116244897 -> 81686.0112
#
#
#
# grid_adaboost_model_001_003
# MAE: 57364.95767226333  -> 57364.9577
# RMSE: 74216.26980500946 -> 74216.2698
#
#
#
#
# grid_gradboost_model_001_001
# MAE: 33055.989282643226  -> 33055.9893
# RMSE: 48681.06989826054 -> 48681.0699
#
#
#
# grid_gradboost_model_001_002
# MAE: 32810.95400567314  -> 32810.9540
# RMSE: 48457.531555013564 -> 48457.5316
#
#
# grid_XGBRegressor_model_001_001
# MAE: 39170.28156548274  -> 39170.2816
# RMSE: 57131.60231542059 -> 57131.6023
#
# grid_XGBRFRegressor_model_001_001
# MAE: 45182.25031357073  -> 45182.2503
# RMSE: 63844.16962078191 -> 63844.1696

# %%
# Import libraries
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format

#import sklearn
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import accuracy_score, confusion_matrix

df = pd.read_csv("/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_002/0261_Project_002_Data/housing.csv")
#df = pd.read_csv("/xx/xx/Desktop/housing.csv")

# Dropping Missing Values
df.dropna(axis=0, inplace=True)

## X, y (features and labels)
X = df.drop(columns=["median_house_value"])
y = df["median_house_value"].copy()


## Feature Scaling
##Z-Score
import scipy.stats as stats

stats.zscore(a=X.select_dtypes('float'), axis=0)
feat1 = X.select_dtypes("float").apply(lambda x: stats.zscore(a=x, axis=0, ddof=0, nan_policy='propagate'))
feat1.agg(["mean", "std"])


### Feature Engineering
##Ocean Proximity
## Will use replace and True:1, False: 0
dummies_ocean_prox = pd.get_dummies(data=X["ocean_proximity"], drop_first=False)
dummies_ocean_prox = dummies_ocean_prox.replace({True: 1, False: 0})
dummies_ocean_prox.head(3)

features = pd.concat([feat1, dummies_ocean_prox], axis=1)
features

#### Features and Labels for Model Creation
X02 = features.copy()
y02 = df["median_house_value"].copy()

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
# Helper Functions 001
##
def model_stats(model, model_used, model_name, param_grid_used=True):
    """
    Receives Trained Model information and outputs general information about the trained model

    Inputs
    model - Trained Model Variable Name. E.g. grid_model_001_001
    model_used - Name of the Model used to show which type of model the results are for. E.g. LogisticRegression
    model_name - Variable Name of the Model Object Created. E.g. log_model_001_001
    """
    print(f"Model: {model_used}")
    #print("\n")
    print(f" Model Object Variable Name: {model_name}")
    #print("\n")
    print(f"Trained Model Variable Name: {model}")
    #print("\n")
    if param_grid_used==True:
        parameter_grid_used = model.param_grid
        estimator_model = model.estimator
        best_params_model = model.best_params_
        best_estimator_model = model.best_estimator_
    
        print(f"Parameter Grid:\n{parameter_grid_used}")
        print("\n")
        print(f"Estimator:\n{estimator_model}")
        print("\n")
        print(f"Best Parameters:\n{best_params_model}")
        print("\n")
        print(f"Best Estimator Chosen:\n{best_estimator_model}")
    elif param_grid_used==False:
        return
    else:
        return
    print("\n")

# %%
# Helper Functions 003
## Metrics Regression
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score, r2_score

##explained_variance_score Best score is 1


mae_score_model_name = []
rmse_score_model_name = []
explained_var_score_model_name = []
r2_score_model_name = []

def show_model_metrics_regression(model, 
                                  X_test, 
                                  y_test, 
                                  whole_y=y, 
                                  to_append=True, 
                                  mae_score_list=mae_score_model_name,
                                  rmse_score_list=rmse_score_model_name,
                                  explained_var_score_list=explained_var_score_model_name,
                                  r2_score_list=r2_score_model_name):
    """
    Function that receives several inputs and outputs several metrics for a classification model.
    
    Inputs:
    * model - Trained Model
    * X_test - Either Validation or Test data for the model to predict and gather metrics.
    * y_test - Either Validation or Test data for the model to predict and gather metrics and to compute the mean and median.
    * whole_y - Accepts the class label "y" to compute the mean and median. By default is "y".
        Note: Since it is computing the mean it will only accept a single column.
        If more columns are on the labels will need to disable this

    Outputs
    
    MAE Mean Absolute Error - mean_absolute_error
    RMSE Root Mean Squared Error - mean_squared_error
    """
    ## Model predictions
    model_predictions = model.predict(X_test)

    ### MAE, MSE, RMSE
    mae_score = mean_absolute_error(y_true=y_test, y_pred=model_predictions, sample_weight=None, multioutput='uniform_average')
    rmse_score = np.sqrt(mean_squared_error(y_true=y_test, y_pred=model_predictions, sample_weight=None, multioutput='uniform_average', squared=True))
    explained_var_score = explained_variance_score(y_true=y_test, y_pred=model_predictions, sample_weight=None, multioutput='uniform_average', force_finite=True)
    r2_scores = r2_score(y_true=y_test, y_pred=model_predictions)#, sample_weight=None, multioutput='uniform_average',force_finite=True)
    print('\n')
    print(f"  Median of y: {np.median(whole_y)}")
    print(f"y_test Median: {np.median(y_test)}")
    print('\n')
    print(f"  Mean of y: {whole_y.mean()}")
    print(f"y_test Mean: {y_test.mean()}")
    print('\n')
    print(f" MAE: {mae_score}  -> {(mae_score):.4f}")
    print(f"RMSE: {rmse_score} -> {(rmse_score):.4f}")
    print(f"R2 Coefficient of Determination: {r2_scores} -> {(r2_scores):.4f}")
    print("\n")
    print(f"Model RMSE is {(rmse_score):.4f} and that is on the {(rmse_score * 100)/(np.mean(y)):.6f} % error range")
    print(f"explained_var_score: {explained_var_score}")
    if to_append == True:
        mae_score_list.append(mae_score)
        rmse_score_list.append(rmse_score)
        explained_var_score_list.append(explained_var_score)
        r2_score_list.append(r2_score)
    else:
        return
    print("\n")

# %%
# Helper Functions 003
## Metrics Regression
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score, r2_score

##explained_variance_score Best score is 1


mae_score_model_name = []
rmse_score_model_name = []
explained_var_score_model_name = []
r2_score_model_name = []

def show_model_metrics_regression(model, 
                                  X_test, 
                                  y_test, 
                                  whole_y=y, 
                                  to_append=True, 
                                  mae_score_list=mae_score_model_name,
                                  rmse_score_list=rmse_score_model_name,
                                  explained_var_score_list=explained_var_score_model_name,
                                  r2_score_list=r2_score_model_name):
    """
    Function that receives several inputs and outputs several metrics for a classification model.
    
    Inputs:
    * model - Trained Model
    * X_test - Either Validation or Test data for the model to predict and gather metrics.
    * y_test - Either Validation or Test data for the model to predict and gather metrics and to compute the mean and median.
    * whole_y - Accepts the class label "y" to compute the mean and median. By default is "y".
        Note: Since it is computing the mean it will only accept a single column.
        If more columns are on the labels will need to disable this

    Outputs
    
    MAE Mean Absolute Error - mean_absolute_error
    RMSE Root Mean Squared Error - mean_squared_error
    """
    ## Model predictions
    model_predictions = model.predict(X_test)

    ### MAE, MSE, RMSE
    mae_score = mean_absolute_error(y_true=y_test, y_pred=model_predictions, sample_weight=None, multioutput='uniform_average')
    rmse_score = np.sqrt(mean_squared_error(y_true=y_test, y_pred=model_predictions, sample_weight=None, multioutput='uniform_average', squared=True))
    explained_var_score = explained_variance_score(y_true=y_test, y_pred=model_predictions, sample_weight=None, multioutput='uniform_average', force_finite=True)
    r2_scores = r2_score(y_true=y_test, y_pred=model_predictions)#, sample_weight=None, multioutput='uniform_average',force_finite=True)
    print('\n')
    print(f"  Median of y: {np.median(whole_y)}")
    print(f"y_test Median: {np.median(y_test)}")
    print('\n')
    print(f"  Mean of y: {whole_y.mean()}")
    print(f"y_test Mean: {y_test.mean()}")
    print('\n')
    print(f" MAE: {mae_score}  -> {(mae_score):.4f}")
    print(f"RMSE: {rmse_score} -> {(rmse_score):.4f}")
    print(f"R2 Coefficient of Determination: {r2_scores} -> {(r2_scores):.4f}")
    print("\n")
    print(f"Model RMSE is {(rmse_score):.4f} and that is on the {(rmse_score * 100)/(np.mean(y)):.6f} % error range")
    print(f"explained_var_score: {explained_var_score}")
    if to_append == True:
        mae_score_list.append(mae_score)
        rmse_score_list.append(rmse_score)
        explained_var_score_list.append(explained_var_score)
        r2_score_list.append(r2_score)
    else:
        return
    print("\n")

# %% [markdown]
# y_mean:206864.41315519012
#
#
# linreg_model_001_001
# mae_linreg_model_001_001: 49564.9322
# rmse_linreg_model_001_001: 67706.0319
#
#
#
# model_lin_reg_poly_deg1
# mae_poly_reg_valid_error_deg1: 49564.9322051044
# rmse_poly_reg_valid__error_deg1: 67706.03188712957
#
#
# grid_elasticnet_model_001_001
# mae_grid_elasticnet_model_001_001: 49551.9350
# rmse_grid_elasticnet_model_001_001: 67672.2605
#
#
# grid_elasticnet_model_001_002
# mae_grid_elasticnet_model_001_002: 49557.1333
# rmse_grid_elasticnet_model_001_002: 67685.1233
#
#
#
# grid_elasticnet_model_001_003
# mae_grid_elasticnet_model_001_003: 49555.8331
# rmse_grid_elasticnet_model_001_003: 67681.8270
#
#
# grid_logreg_model_001_001
# ####################################################################################
# grid_logreg_model_001_001
# LogisticRegression(C=59948425.03189421, l1_ratio=0.6666666666666666,
#                    max_iter=5000, multi_class='ovr', penalty='elasticnet',
#                    solver='saga', tol=0.1)
#
# grid_logreg_model_001_001.best_params_
# {'C': 59948425.03189421, 'l1_ratio': 0.6666666666666666}
#
#
# print(grid_logreg_model_001_001.best_estimator_)
# LogisticRegression(C=59948425.03189421, l1_ratio=0.6666666666666666,
#                    max_iter=5000, multi_class='ovr', penalty='elasticnet',
#                    solver='saga', tol=0.1)
#
#
#
# mae_score_logreg_model_001_001_valid: 153733.41997063142
#
# rmse_score_logreg_model_001_001_valid: 198670.25865081637
#
#
# ####################################################################################
#
#
#
#
#
# knn_model_001_002
# mae_knn_model_001_002: 41275.4747
# rmse_knn_model_001_002: 61374.9004
#
#
#
# grid_svm_model_001_001
# mae_grid_svm_model_001_001: 84320.5295
# rmse_grid_svm_model_001_001: 113044.2543
#
#
#
#
# grid_tree_model_001_001
# mae_grid_tree_model_001_001: 41109.1380
# rmse_grid_tree_model_001_001: 64120.2450
#
#
#
# grid_tree_model_001_002
# mae_grid_tree_model_001_002: 41109.1380
# rmse_grid_tree_model_001_002: 64120.2450
#
#
# grid_tree_model_001_003
# mae_grid_tree_model_001_003: 43144.5291
# rmse_grid_tree_model_001_003: 66740.0776
#
#
#
#
# grid_forest_model_001_001
# mae_grid_forest_model_001_001: 31867.0469
# rmse_grid_forest_model_001_001: 48100.5936
#
#
#
# grid_forest_model_001_002
# mae_grid_forest_model_001_002: 31878.6493
# rmse_grid_forest_model_001_002: 48090.5366
#
#
#
# grid_adaboost_model_001_001
# mae_grid_adaboost_model_001_001: 61086.5882
# rmse_grid_adaboost_model_001_001: 76693.2086
#
#
#
#
# grid_adaboost_model_001_002
# mae_grid_adaboost_model_001_002: 67291.5035
# rmse_grid_adaboost_model_001_002: 81686.0112
#
#
#
# grid_adaboost_model_001_003
# mae_grid_adaboost_model_001_003: 57364.9577
# rmse_grid_adaboost_model_001_003: 74216.2698
#
#
#
#
# grid_gradboost_model_001_001
# mae_grid_gradboost_model_001_001: 33055.9893
# rmse_grid_gradboost_model_001_001: 48681.0699
#
#
# grid_gradboost_model_001_002
# mae_grid_gradboost_model_001_002: 32810.9540
# rmse_grid_gradboost_model_001_002: 48457.5316
#
# grid_XGBRegressor_model_001_001
# mae_grid_XGBRegressor_model_001_001: 39170.2816
# rmse_grid_XGBRegressor_model_001_001: 57131.6023
#
# grid_XGBRFRegressor_model_001_001
# mae_grid_XGBRFRegressor_model_001_001: 45182.2503
# rmse_grid_XGBRFRegressor_model_001_001: 63844.1696

# %%
df_results_01 = pd.DataFrame([

{"linreg_model_001_001": 49564.9322,
"poly_reg_valid_error_deg1": 49564.9322,
"grid_elasticnet_model_001_001": 49551.9350,
"grid_elasticnet_model_001_002": 49557.1333,
"grid_elasticnet_model_001_003": 49555.8331,
"score_logreg_model_001_001_valid": 153733.4200,
"knn_model_001_002": 41275.4747,
"grid_svm_model_001_001": 84320.5295,
"grid_tree_model_001_001": 41109.1380,
"grid_tree_model_001_002": 41109.1380,
"grid_tree_model_001_003": 43144.5291,
"grid_forest_model_001_001": 31867.0469,
"grid_forest_model_001_002": 31878.6493,
"grid_adaboost_model_001_001": 61086.5882,
"grid_adaboost_model_001_002": 67291.5035,
"grid_adaboost_model_001_003": 57364.9577,
"grid_gradboost_model_001_001": 33055.9893,
"grid_gradboost_model_001_002": 32810.9540,
'grid_XGBRegressor_model_001_001': 39170.2816,
'grid_XGBRFRegressor_model_001_001': 45182.2503},
{"linreg_model_001_001": 67706.0319,
"poly_reg_valid_error_deg1": 67706.0319,
"grid_elasticnet_model_001_001": 67672.2605,
"grid_elasticnet_model_001_002": 67685.1233,
"grid_elasticnet_model_001_003": 67681.8270,
"score_logreg_model_001_001_valid": 198670.2587,
"knn_model_001_002": 61374.9004,
"grid_svm_model_001_001": 113044.2543,
"grid_tree_model_001_001": 64120.2450,
"grid_tree_model_001_002": 64120.2450,
"grid_tree_model_001_003": 66740.0776,
"grid_forest_model_001_001": 48100.5936,
"grid_forest_model_001_002": 48090.5366,
"grid_adaboost_model_001_001": 76693.2086,
"grid_adaboost_model_001_002": 81686.0112,
"grid_adaboost_model_001_003": 74216.2698,
"grid_gradboost_model_001_001": 48681.0699,
"grid_gradboost_model_001_002": 48457.5316,
'grid_XGBRegressor_model_001_001': 57131.6023,
'grid_XGBRFRegressor_model_001_001': 63844.1696}
])





df_results_01 = df_results_01.transpose().rename(columns={0:"mae", 1:"rmse"})
df_results_01
# Out:
#                                         mae      rmse
# linreg_model_001_001               49564.93  67706.03
# poly_reg_valid_error_deg1          49564.93  67706.03
# grid_elasticnet_model_001_001      49551.93  67672.26
# grid_elasticnet_model_001_002      49557.13  67685.12
# grid_elasticnet_model_001_003      49555.83  67681.83
# score_logreg_model_001_001_valid  153733.42 198670.26
# knn_model_001_002                  41275.47  61374.90
# grid_svm_model_001_001             84320.53 113044.25
# grid_tree_model_001_001            41109.14  64120.25
# grid_tree_model_001_002            41109.14  64120.25
# grid_tree_model_001_003            43144.53  66740.08
# grid_forest_model_001_001          31867.05  48100.59
# grid_forest_model_001_002          31878.65  48090.54
# grid_adaboost_model_001_001        61086.59  76693.21
# grid_adaboost_model_001_002        67291.50  81686.01
# grid_adaboost_model_001_003        57364.96  74216.27
# ...

# %%
df_results_saved_01 = df_results_01.to_csv(path_or_buf= '/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_002/0261_Project_002_Data/Saved_Results/df_results_01.csv',
                                           sep = ',',
                                           na_rep = '',
                                           float_format = None,
                                           columns = None,
                                           header = True,
                                           index = True,
                                           index_label = None,
                                           mode = 'w',
                                           encoding = None,
                                           compression = 'infer',
                                           quoting = None,
                                           quotechar = '"',
                                           lineterminator = None,
                                           chunksize = None,
                                           date_format = None,
                                           doublequote = True,
                                           escapechar = None,
                                           decimal = '.',
                                           errors = 'strict',
                                           storage_options = None)

# %%
df_results_loaded_01 = pd.read_csv('/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_002/0261_Project_002_Data/Saved_Results/df_results_01.csv',
                                   index_col='Unnamed: 0')

df_results_loaded_01 = df_results_loaded_01.rename(columns={'mae':'mae_score', 'rmse':'rmse_score'})
df_results_loaded_01
# Out:
#                                    mae_score  rmse_score
# linreg_model_001_001                49564.93    67706.03
# poly_reg_valid_error_deg1           49564.93    67706.03
# grid_elasticnet_model_001_001       49551.93    67672.26
# grid_elasticnet_model_001_002       49557.13    67685.12
# grid_elasticnet_model_001_003       49555.83    67681.83
# score_logreg_model_001_001_valid   153733.42   198670.26
# knn_model_001_002                   41275.47    61374.90
# grid_svm_model_001_001              84320.53   113044.25
# grid_tree_model_001_001             41109.14    64120.25
# grid_tree_model_001_002             41109.14    64120.25
# grid_tree_model_001_003             43144.53    66740.08
# grid_forest_model_001_001           31867.05    48100.59
# grid_forest_model_001_002           31878.65    48090.54
# grid_adaboost_model_001_001         61086.59    76693.21
# grid_adaboost_model_001_002         67291.50    81686.01
# ...

# %%
df_results_loaded_01 = pd.read_csv('/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_002/0261_Project_002_Data/Saved_Results/df_results_01.csv',
                                   index_col='Unnamed: 0')
df_results_loaded_01 = df_results_loaded_01.rename(columns={'mae':'mae_score', 'rmse':'rmse_score'})

df_results_loaded_01
# Out:
#                                    mae_score  rmse_score
# linreg_model_001_001                49564.93    67706.03
# poly_reg_valid_error_deg1           49564.93    67706.03
# grid_elasticnet_model_001_001       49551.93    67672.26
# grid_elasticnet_model_001_002       49557.13    67685.12
# grid_elasticnet_model_001_003       49555.83    67681.83
# score_logreg_model_001_001_valid   153733.42   198670.26
# knn_model_001_002                   41275.47    61374.90
# grid_svm_model_001_001              84320.53   113044.25
# grid_tree_model_001_001             41109.14    64120.25
# grid_tree_model_001_002             41109.14    64120.25
# grid_tree_model_001_003             43144.53    66740.08
# grid_forest_model_001_001           31867.05    48100.59
# grid_forest_model_001_002           31878.65    48090.54
# grid_adaboost_model_001_001         61086.59    76693.21
# grid_adaboost_model_001_002         67291.50    81686.01
# ...

# %%
## Without XGBoost Models
df_all_model_results = pd.read_csv('/Users/luis/Documents/Proyects_To_Export/0261_DS_Projects/venv_0261_DS_Projects_311/Projects/0261_Project_002/0261_Project_002_Notebooks_Mine/0261_Project_002_00_To_Pre_Export/To_Pre_Export/saved_results_info/df_all_model_results_to_export.csv')

df_all_model_results
# Out:
#                                        mae_score  rmse_score  explained_var  \
# linreg_model_001_001_valid                  0.66        0.66       67706.03
# linreg_model_001_001_test                   0.64        0.64       70852.90
# linreg_poly_deg01_model_001_001_valid       0.66        0.66       67706.03
# linreg_poly_deg01_model_001_001_test        0.64        0.64       70852.90
# elasticnet_model_001_001_valid          67672.26        0.66           0.66
# elasticnet_model_001_001_test               0.64    70833.59       51251.07
# elasticnet_model_001_002_valid              0.66        0.66       67685.12
# elasticnet_model_001_002_test           70840.69        0.64           0.64
# elasticnet_model_001_003_valid              0.66    67681.83       49555.83
# elasticnet_model_001_003_test               0.64        0.64       70838.84
# knn_model_001_002_valid                     0.72        0.72       41275.47
# ...
